# %%
import nbimporter
# %run load_df.ipynb
### Replace with import load_df.py

# %%
file = "data\proteinGroups_PNNL_TMT_SC_Chip1_A.txt"
data = readin(file)

# %%
#Labels to use in the graph, by column name.
#If you are unsure what your columns are named, run:
#print(data.columns.values)
channels = {
    'Reporter intensity 1 PNNL SC Chip1 A':'Cell 1',
}

blank = 'Reporter intensity 9 PNNL SC Chip1 A'

# %%
hist_ratios(data, channels, blank)
# Out:
# Cell 1:
# 687 of 870 are 0.0
# Average: 0.0145
# 95% Threshold: 0.0827

# %%
hist_ratios(data, channels, blank, show_zeros=True, details=False)
# Out:
# Cell 1:
# 687 of 870 are 0.0
# Average: 0.0145
# 95% Threshold: 0.0827
